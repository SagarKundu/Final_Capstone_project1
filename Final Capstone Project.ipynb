# %% [markdown]
# ## Week 3 Assignment

# %%
import numpy as np 
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim
import requests 
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from bs4 import BeautifulSoup
import xml

# %%
url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(url,'lxml')

# %%
table_post = soup.find('table')
fields = table_post.find_all('td')

postcode = []
borough = []
neighbourhood = []

for i in range(0, len(fields), 3):
    postcode.append(fields[i].text.strip())
    borough.append(fields[i+1].text.strip())
    neighbourhood.append(fields[i+2].text.strip())
        
df = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()
df.columns = ['Postcode', 'Borough', 'Neighbourhood']
df.head()
# Out:
#                                          Postcode  \
# 0                                 M1ANot assigned
# 1                 M4ANorth York(Victoria Village)
# 2  M7AQueen's Park(Ontario Provincial Government)
# 3                 M1BScarborough(Malvern / Rouge)
# 4  M4BEast York(Parkview Hill / Woodbine Gardens)
#
#                                            Borough  \
# 0                                  M2ANot assigned
# 1  M5ADowntown Toronto(Regent Park / Harbourfront)
# 2                                  M8ANot assigned
# 3                                  M2BNot assigned
# 4    M5BDowntown Toronto(Garden District, Ryerson)
#
#                                       Neighbourhood
# 0                          M3ANorth York(Parkwoods)
# 1  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 2                    M9AEtobicoke(Islington Avenue)
# 3                     M3BNorth York(Don Mills)North
# 4                          M6BNorth York(Glencairn)

# %%
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.dropna(subset=['Borough'], inplace=True)

df.head(20)
# Out:
#                                              Postcode  \
# 0                                     M1ANot assigned
# 1                     M4ANorth York(Victoria Village)
# 2      M7AQueen's Park(Ontario Provincial Government)
# 3                     M1BScarborough(Malvern / Rouge)
# 4      M4BEast York(Parkview Hill / Woodbine Gardens)
# 5                                     M7BNot assigned
# 6   M1CScarborough(Rouge Hill / Port Union / Highl...
# 7                      M4CEast York(Woodbine Heights)
# 8                                     M7CNot assigned
# 9   M1EScarborough(Guildwood / Morningside / West ...
# 10                       M4EEast Toronto(The Beaches)
# 11                                    M7ENot assigned
# 12                             M1GScarborough(Woburn)
# 13                              M4GEast York(Leaside)
# 14                                    M7GNot assigned
# 15                          M1HScarborough(Cedarbrae)
# 16                     M4HEast York(Thorncliffe Park)
# 17                                    M7HNot assigned
# 18                M1JScarborough(Scarborough Village)
# 19       M4JEast YorkEast Toronto(The Danforth  East)
#
#                                               Borough  \
# 0                                     M2ANot assigned
# 1     M5ADowntown Toronto(Regent Park / Harbourfront)
# 2                                     M8ANot assigned
# 3                                     M2BNot assigned
# 4       M5BDowntown Toronto(Garden District, Ryerson)
# 5                                     M8BNot assigned
# 6                                     M2CNot assigned
# 7                 M5CDowntown Toronto(St. James Town)
# 8                                     M8CNot assigned
# 9                                     M2ENot assigned
# 10                   M5EDowntown Toronto(Berczy Park)
# 11                                    M8ENot assigned
# 12                                    M2GNot assigned
# 13            M5GDowntown Toronto(Central Bay Street)
# 14                                    M8GNot assigned
# 15                   M2HNorth York(Hillcrest Village)
# 16    M5HDowntown Toronto(Richmond / Adelaide / King)
# 17                                    M8HNot assigned
# 18      M2JNorth York(Fairview / Henry Farm / Oriole)
# 19  M5JDowntown Toronto(Harbourfront East / Union ...
#
#                                         Neighbourhood
# 0                            M3ANorth York(Parkwoods)
# 1    M6ANorth York(Lawrence Manor / Lawrence Heights)
# 2                      M9AEtobicoke(Islington Avenue)
# 3                       M3BNorth York(Don Mills)North
# 4                            M6BNorth York(Glencairn)
# 5   M9BEtobicoke(West Deane Park / Princess Garden...
# 6      M3CNorth York(Don Mills)South(Flemingdon Park)
# 7                         M6CYork(Humewood-Cedarvale)
# 8   M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 9                                     M3ENot assigned
# 10                       M6EYork(Caledonia-Fairbanks)
# 11                                    M9ENot assigned
# 12                                    M3GNot assigned
# 13                      M6GDowntown Toronto(Christie)
# 14                                    M9GNot assigned
# 15  M3HNorth York(Bathurst Manor / Wilson Heights ...
# 16     M6HWest Toronto(Dufferin / Dovercourt Village)
# 17                                    M9HNot assigned
# 18    M3JNorth York(Northwood Park / York University)
# 19         M6JWest Toronto(Little Portugal / Trinity)

# %%
df = df.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df.columns = ['Postcode', 'Borough', 'Neighbourhood']
df
# Out:
#                                              Postcode  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# 16     M1WScarborough(Steeles West / L'Amoreaux West)
# 17                        M1XScarborough(Upper Rouge)
# 18                                    M1YNot assigned
# 19                                    M1ZNot assigned
# 20                    M4ANorth York(Victoria Village)
# 21     M4BEast York(Parkview Hill / Woodbine Gardens)
# 22                     M4CEast York(Woodbine Heights)
# 23                       M4EEast Toronto(The Beaches)
# 24                              M4GEast York(Leaside)
# 25                     M4HEast York(Thorncliffe Park)
# 26       M4JEast YorkEast Toronto(The Danforth  East)
# 27     M4KEast Toronto(The Danforth West / Riverdale)
# 28   M4LEast Toronto(India Bazaar / The Beaches West)
# 29                   M4MEast Toronto(Studio District)
# 30                  M4NCentral Toronto(Lawrence Park)
# 31               M4PCentral Toronto(Davisville North)
# 32             M4RCentral Toronto(North Toronto West)
# 33                     M4SCentral Toronto(Davisville)
# 34   M4TCentral Toronto(Moore Park / Summerhill East)
# 35  M4VCentral Toronto(Summerhill West / Rathnelly...
# 36                      M4WDowntown Toronto(Rosedale)
# 37  M4XDowntown Toronto(St. James Town / Cabbagetown)
# 38          M4YDowntown Toronto(Church and Wellesley)
# 39                                    M4ZNot assigned
# 40     M7AQueen's Park(Ontario Provincial Government)
# 41                                    M7BNot assigned
# 42                                    M7CNot assigned
# 43                                    M7ENot assigned
# 44                                    M7GNot assigned
# 45                                    M7HNot assigned
# 46                                    M7JNot assigned
# 47                                    M7KNot assigned
# 48                                    M7LNot assigned
# 49                                    M7MNot assigned
# 50                                    M7NNot assigned
# 51                                    M7PNot assigned
# 52  M7RMississaugaCanada Post Gateway Processing C...
# 53                                    M7SNot assigned
# 54                                    M7TNot assigned
# 55                                    M7VNot assigned
# 56                                    M7WNot assigned
# 57                                    M7XNot assigned
# 58  M7YEast TorontoBusiness reply mail Processing ...
# 59                                    M7ZNot assigned
#
#                                               Borough  \
# 0                                     M2ANot assigned
# 1                                     M2BNot assigned
# 2                                     M2CNot assigned
# 3                                     M2ENot assigned
# 4                                     M2GNot assigned
# 5                    M2HNorth York(Hillcrest Village)
# 6       M2JNorth York(Fairview / Henry Farm / Oriole)
# 7                      M2KNorth York(Bayview Village)
# 8            M2LNorth York(York Mills / Silver Hills)
# 9             M2MNorth York(Willowdale / Newtonbrook)
# 10                     M2NNorth York(Willowdale)South
# 11                     M2PNorth York(York Mills West)
# 12                      M2RNorth York(Willowdale)West
# 13                                    M2SNot assigned
# 14                                    M2TNot assigned
# 15                                    M2VNot assigned
# 16                                    M2WNot assigned
# 17                                    M2XNot assigned
# 18                                    M2YNot assigned
# 19                                    M2ZNot assigned
# 20    M5ADowntown Toronto(Regent Park / Harbourfront)
# 21      M5BDowntown Toronto(Garden District, Ryerson)
# 22                M5CDowntown Toronto(St. James Town)
# 23                   M5EDowntown Toronto(Berczy Park)
# 24            M5GDowntown Toronto(Central Bay Street)
# 25    M5HDowntown Toronto(Richmond / Adelaide / King)
# 26  M5JDowntown Toronto(Harbourfront East / Union ...
# 27  M5KDowntown Toronto(Toronto Dominion Centre / ...
# 28  M5LDowntown Toronto(Commerce Court / Victoria ...
# 29  M5MNorth York(Bedford Park / Lawrence Manor East)
# 30                       M5NCentral Toronto(Roselawn)
# 31       M5PCentral Toronto(Forest Hill North & West)
# 32  M5RCentral Toronto(The Annex / North Midtown /...
# 33  M5SDowntown Toronto(University of Toronto / Ha...
# 34  M5TDowntown Toronto(Kensington Market / Chinat...
# 35  M5VDowntown Toronto(CN Tower / King and Spadin...
# 36  M5WDowntown TorontoStn A PO Boxes25 The Esplan...
# 37  M5XDowntown Toronto(First Canadian Place / Und...
# 38                                    M5YNot assigned
# 39                                    M5ZNot assigned
# 40                                    M8ANot assigned
# 41                                    M8BNot assigned
# 42                                    M8CNot assigned
# 43                                    M8ENot assigned
# 44                                    M8GNot assigned
# 45                                    M8HNot assigned
# 46                                    M8JNot assigned
# 47                                    M8KNot assigned
# 48                                    M8LNot assigned
# 49                                    M8MNot assigned
# 50                                    M8NNot assigned
# 51                                    M8PNot assigned
# 52                                    M8RNot assigned
# 53                                    M8SNot assigned
# 54                                    M8TNot assigned
# 55  M8VEtobicoke(New Toronto / Mimico South / Humb...
# 56              M8WEtobicoke(Alderwood / Long Branch)
# 57  M8XEtobicoke(The Kingsway / Montgomery Road / ...
# 58  M8YEtobicoke(Old Mill South / King's Mill Park...
# 59  M8ZEtobicoke(Mimico NW / The Queensway West / ...
#
#                                         Neighbourhood
# 0                            M3ANorth York(Parkwoods)
# 1                       M3BNorth York(Don Mills)North
# 2      M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                     M3ENot assigned
# 4                                     M3GNot assigned
# 5   M3HNorth York(Bathurst Manor / Wilson Heights ...
# 6     M3JNorth York(Northwood Park / York University)
# 7         M3KNorth York(Downsview)East  (CFB Toronto)
# 8                        M3LNorth York(Downsview)West
# 9                     M3MNorth York(Downsview)Central
# 10                  M3NNorth York(Downsview)Northwest
# 11                                    M3PNot assigned
# 12                                    M3RNot assigned
# 13                                    M3SNot assigned
# 14                                    M3TNot assigned
# 15                                    M3VNot assigned
# 16                                    M3WNot assigned
# 17                                    M3XNot assigned
# 18                                    M3YNot assigned
# 19                                    M3ZNot assigned
# 20   M6ANorth York(Lawrence Manor / Lawrence Heights)
# 21                           M6BNorth York(Glencairn)
# 22                        M6CYork(Humewood-Cedarvale)
# 23                       M6EYork(Caledonia-Fairbanks)
# 24                      M6GDowntown Toronto(Christie)
# 25     M6HWest Toronto(Dufferin / Dovercourt Village)
# 26         M6JWest Toronto(Little Portugal / Trinity)
# 27  M6KWest Toronto(Brockton / Parkdale Village / ...
# 28  M6LNorth York(North Park / Maple Leaf Park / U...
# 29  M6MYork(Del Ray / Mount Dennis / Keelsdale and...
# 30            M6NYork(Runnymede / The Junction North)
# 31    M6PWest Toronto(High Park / The Junction South)
# 32           M6RWest Toronto(Parkdale / Roncesvalles)
# 33               M6SWest Toronto(Runnymede / Swansea)
# 34                                    M6TNot assigned
# 35                                    M6VNot assigned
# 36                                    M6WNot assigned
# 37                                    M6XNot assigned
# 38                                    M6YNot assigned
# 39                                    M6ZNot assigned
# 40                     M9AEtobicoke(Islington Avenue)
# 41  M9BEtobicoke(West Deane Park / Princess Garden...
# 42  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 43                                    M9ENot assigned
# 44                                    M9GNot assigned
# 45                                    M9HNot assigned
# 46                                    M9JNot assigned
# 47                                    M9KNot assigned
# 48                       M9LNorth York(Humber Summit)
# 49                   M9MNorth York(Humberlea / Emery)
# 50                                    M9NYork(Weston)
# 51                            M9PEtobicoke(Westmount)
# 52  M9REtobicoke(Kingsview Village / St. Phillips ...
# 53                                    M9SNot assigned
# 54                                    M9TNot assigned
# 55  M9VEtobicoke(South Steeles / Silverstone / Hum...
# 56  M9WEtobicokeNorthwest(Clairville / Humberwood ...
# 57                                    M9XNot assigned
# 58                                    M9YNot assigned
# 59                                    M9ZNot assigned

# %%
df.shape
# Out:
# (60, 3)

# %%
df_geo = pd.read_csv('http://cocl.us/Geospatial_data')
df_geo.columns = ['Postcode', 'Latitude', 'Longitude']
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-cbd1aa374b40> in <module>
# ----> 1 df_geo = pd.read_csv('http://cocl.us/Geospatial_data')
#       2 df_geo.columns = ['Postcode', 'Latitude', 'Longitude']
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     429     # See https://github.com/python/mypy/issues/1297
#     430     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 431         filepath_or_buffer, encoding, compression
#     432     )
#     433     kwds["compression"] = compression
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     170
#     171     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
# --> 172         req = urlopen(filepath_or_buffer)
#     173         content_encoding = req.headers.get("Content-Encoding", None)
#     174         if content_encoding == "gzip":
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 308: Permanent Redirect

# %%
df_pos = pd.merge(df, df_geo, on=['Postcode'], how='inner')

df_tor = df_pos[['Borough', 'Neighbourhood', 'Postcode', 'Latitude', 'Longitude']].copy()

df_tor.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9cc280a20fcd> in <module>
# ----> 1 df_pos = pd.merge(df, df_geo, on=['Postcode'], how='inner')
#       2
#       3 df_tor = df_pos[['Borough', 'Neighbourhood', 'Postcode', 'Latitude', 'Longitude']].copy()
#       4
#       5 df_tor.head()
#
# NameError: name 'df_geo' is not defined
